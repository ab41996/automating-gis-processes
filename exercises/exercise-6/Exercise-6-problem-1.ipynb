# %% [markdown]
# # Problem 1: Temperature Map (8 points)
#
# In this problem, we will work with raster data from the [Finnish Meteorological Institute (FMI)](https://en.ilmatieteenlaitos.fi/), which contains daily average temperatures stored in 10 km by 10 km raster cells. For each year, there is one raster file (we will only work with data from the year 2023), and it contains 365 raster bands—each representing one day of the year, starting from January through to the end of December.
#
# In this exercise, we will work with the raster bands, extract the necessary information, and perform raster calculations.

# %% [markdown]
# ## (1a) - Read the raster data (1 point)
#
# As the first step read the raster file from data directory `data/tday_2023.tif`. Print the raster metadata.

# %%
import rioxarray

raster_file = 'data/tday_2023.tif'

# Load raster
temp_raster = rioxarray.open_rasterio(raster_file)

# %% [markdown]
# ## (1b) - Maximum temperatures per day (2 points)
#
# We aim to extract the maximum temperature across the country for each day of summer. Since each day's data is stored as a raster band, we need to iterate through the bands to the desired value — the maximum temperature for that day (i.e., the highest pixel value) from the relevant bands. We will do this only for the Summer, which spans from June 1st (the 152nd day of the year) to August 31st (the 243rd day of the year).
#
# For each day, print the day number and the maximum temperature using a f-string formatted to two decimal places, like so: `On summer day number --, the maximum temperature in the country is: --`.

# %%
temps = []
for i in range(152,244):
    temp = temp_raster.sel(band=i).max().item()
    print(f"On summer day number {i}, the maximum temperature is: {temp}")
    temps.append((i,temp))
# Out:
# On summer day number 152, the maximum temperature is: 10.600000381469727
# On summer day number 153, the maximum temperature is: 9.300000190734863
# On summer day number 154, the maximum temperature is: 10.899999618530273
# On summer day number 155, the maximum temperature is: 12.300000190734863
# On summer day number 156, the maximum temperature is: 14.300000190734863
# On summer day number 157, the maximum temperature is: 14.0
# On summer day number 158, the maximum temperature is: 13.5
# On summer day number 159, the maximum temperature is: 12.800000190734863
# On summer day number 160, the maximum temperature is: 13.0
# On summer day number 161, the maximum temperature is: 13.800000190734863
# On summer day number 162, the maximum temperature is: 17.200000762939453
# On summer day number 163, the maximum temperature is: 18.399999618530273
# On summer day number 164, the maximum temperature is: 18.600000381469727
# On summer day number 165, the maximum temperature is: 19.200000762939453
# On summer day number 166, the maximum temperature is: 21.299999237060547
# On summer day number 167, the maximum temperature is: 22.899999618530273
# On summer day number 168, the maximum temperature is: 23.200000762939453
# On summer day number 169, the maximum temperature is: 23.5
# On summer day number 170, the maximum temperature is: 22.600000381469727
# On summer day number 171, the maximum temperature is: 23.0
# On summer day number 172, the maximum temperature is: 23.299999237060547
# On summer day number 173, the maximum temperature is: 21.799999237060547
# On summer day number 174, the maximum temperature is: 21.799999237060547
# On summer day number 175, the maximum temperature is: 20.700000762939453
# On summer day number 176, the maximum temperature is: 21.0
# On summer day number 177, the maximum temperature is: 21.899999618530273
# On summer day number 178, the maximum temperature is: 21.299999237060547
# On summer day number 179, the maximum temperature is: 21.399999618530273
# On summer day number 180, the maximum temperature is: 22.700000762939453
# On summer day number 181, the maximum temperature is: 22.399999618530273
# On summer day number 182, the maximum temperature is: 19.600000381469727
# On summer day number 183, the maximum temperature is: 18.399999618530273
# On summer day number 184, the maximum temperature is: 15.800000190734863
# On summer day number 185, the maximum temperature is: 15.399999618530273
# On summer day number 186, the maximum temperature is: 16.5
# On summer day number 187, the maximum temperature is: 18.200000762939453
# On summer day number 188, the maximum temperature is: 18.200000762939453
# On summer day number 189, the maximum temperature is: 17.399999618530273
# On summer day number 190, the maximum temperature is: 17.200000762939453
# On summer day number 191, the maximum temperature is: 18.200000762939453
# On summer day number 192, the maximum temperature is: 22.899999618530273
# On summer day number 193, the maximum temperature is: 23.0
# On summer day number 194, the maximum temperature is: 20.200000762939453
# On summer day number 195, the maximum temperature is: 20.0
# On summer day number 196, the maximum temperature is: 20.799999237060547
# On summer day number 197, the maximum temperature is: 21.899999618530273
# On summer day number 198, the maximum temperature is: 20.5
# On summer day number 199, the maximum temperature is: 18.399999618530273
# On summer day number 200, the maximum temperature is: 18.600000381469727
# On summer day number 201, the maximum temperature is: 18.299999237060547
# On summer day number 202, the maximum temperature is: 17.5
# On summer day number 203, the maximum temperature is: 17.799999237060547
# On summer day number 204, the maximum temperature is: 18.299999237060547
# On summer day number 205, the maximum temperature is: 18.100000381469727
# On summer day number 206, the maximum temperature is: 18.700000762939453
# On summer day number 207, the maximum temperature is: 18.899999618530273
# On summer day number 208, the maximum temperature is: 19.399999618530273
# On summer day number 209, the maximum temperature is: 18.799999237060547
# On summer day number 210, the maximum temperature is: 18.399999618530273
# On summer day number 211, the maximum temperature is: 19.899999618530273
# On summer day number 212, the maximum temperature is: 19.899999618530273
# On summer day number 213, the maximum temperature is: 20.100000381469727
# On summer day number 214, the maximum temperature is: 21.200000762939453
# On summer day number 215, the maximum temperature is: 21.0
# On summer day number 216, the maximum temperature is: 19.399999618530273
# On summer day number 217, the maximum temperature is: 19.299999237060547
# On summer day number 218, the maximum temperature is: 20.299999237060547
# On summer day number 219, the maximum temperature is: 26.899999618530273
# On summer day number 220, the maximum temperature is: 24.799999237060547
# On summer day number 221, the maximum temperature is: 22.5
# On summer day number 222, the maximum temperature is: 22.299999237060547
# On summer day number 223, the maximum temperature is: 19.700000762939453
# On summer day number 224, the maximum temperature is: 19.399999618530273
# On summer day number 225, the maximum temperature is: 19.299999237060547
# On summer day number 226, the maximum temperature is: 20.200000762939453
# On summer day number 227, the maximum temperature is: 20.799999237060547
# On summer day number 228, the maximum temperature is: 21.399999618530273
# On summer day number 229, the maximum temperature is: 20.100000381469727
# On summer day number 230, the maximum temperature is: 18.799999237060547
# On summer day number 231, the maximum temperature is: 18.0
# On summer day number 232, the maximum temperature is: 17.799999237060547
# On summer day number 233, the maximum temperature is: 18.899999618530273
# On summer day number 234, the maximum temperature is: 17.799999237060547
# On summer day number 235, the maximum temperature is: 18.100000381469727
# On summer day number 236, the maximum temperature is: 18.100000381469727
# On summer day number 237, the maximum temperature is: 18.600000381469727
# On summer day number 238, the maximum temperature is: 19.0
# On summer day number 239, the maximum temperature is: 18.799999237060547
# On summer day number 240, the maximum temperature is: 18.399999618530273
# On summer day number 241, the maximum temperature is: 18.0
# On summer day number 242, the maximum temperature is: 18.0
# On summer day number 243, the maximum temperature is: 19.299999237060547

# %% [markdown]
# which summer day was the hottest? Just type in the day number in the cell below.

# %%
# The hottest summer day, just type in the day number as integrer (and not the date)
day_number = max(temps, key=lambda x: x[1])[0]  #replace 0 with the correct value
day_number
# Out:
# 219

# %% [markdown]
# ## (1c) - Work with the "hot" raster band (4 points)
#
# Select the band with the hotetst temperature and store it under the variable name `hot_day_raster`. (1 point)

# %%
# select your raster band here
hot_day_raster=temp_raster.sel(band=day_number)

# %% [markdown]
# Then run the following cell to mask out the null values from your raster.

# %%
import xarray as xr
import numpy as np

hot_day_raster = xr.where(hot_day_raster >= 0, hot_day_raster, np.nan)

# %%
hot_day_raster
# Out:
# <xarray.DataArray (y: 116, x: 68)> Size: 32kB
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]],
#       shape=(116, 68), dtype=float32)
# Coordinates:
#     band         int64 8B 219
#   * x            (x) float64 544B 6.869e+04 7.869e+04 ... 7.287e+05 7.387e+05
#   * y            (y) float64 928B 7.782e+06 7.772e+06 ... 6.642e+06 6.632e+06
#     spatial_ref  int64 8B 0

# %% [markdown]
# Then calculate the following for the selected day (use the same variable names as below): (2 points)
#
# - `average_temp`: a float representing the average temperature.
# - A printed temperature range f-string formatted as: `"Temperature is ranging between -- and --"`, with both values rounded to two decimal places.

# %%
average_temp = hot_day_raster.mean().item()
max_temp=hot_day_raster.max().item()
min_temp=hot_day_raster.min().item()
print(average_temp)
print(f"Temperature is ranging between {min_temp} and {max_temp}")
# Out:
# 21.00836181640625
# Temperature is ranging between 11.300000190734863 and 26.899999618530273

# %% [markdown]
# Now plot your hot day raster. (1 point)

# %%
hot_day_raster.plot()

# %% [markdown]
# ## (1d) - Convert the temperature unit and plot (1 point)
#
# Next, we want to convert the temperatures to degrees Fahrenheit and plot the resulting raster. Name the output raster `hot_day_fahr`.
#
# As we probably remember well from the first period, the conversion formula from Celsius to Fahrenheit is given by:
#
# $$
# T_{\text{Fahrenheit}} = T_{\text{Celsius}} \times \frac{9}{5} + 32
# $$
#
# Finally, plot the `hot_day_fahr` raster.

# %%
hot_day_fahr = hot_day_raster*((9/5))+32

# %%
hot_day_fahr.max().item()
# Out:
# 80.41999816894531
